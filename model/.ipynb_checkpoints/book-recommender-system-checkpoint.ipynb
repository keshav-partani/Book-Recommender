# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
books = pd.read_csv('dataset/Books.csv')
ratings = pd.read_csv('dataset/Ratings.csv')
users = pd.read_csv('dataset/Users.csv')
# Out:
# /tmp/ipykernel_7465/3128739695.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('dataset/Books.csv')

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
print(books.shape)
print(users.shape)
print(ratings.shape)
# Out:
# (271360, 8)
# (278858, 3)
# (1149780, 3)

# %%
books.isna().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isna().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isna().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
ratings['Book-Rating'].value_counts()
# Out:
# Book-Rating
# 0     716109
# 8     103736
# 10     78610
# 7      76457
# 9      67541
# 5      50974
# 6      36924
# 4       8904
# 3       5996
# 2       2759
# 1       1770
# Name: count, dtype: int64

# %% [markdown]
# ## Popularity Based Recommendation System

# %%
ratings_with_name = ratings.merge(books, on="ISBN")
ratings_with_name
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1         276726  0155061224            5
# 2         276727  0446520802            0
# 3         276729  052165615X            3
# 4         276729  0521795028            6
# ...          ...         ...          ...
# 1031131   276704  0876044011            0
# 1031132   276704  1563526298            9
# 1031133   276706  0679447156            0
# 1031134   276709  0515107662           10
# 1031135   276721  0590442449           10
#
#                                                 Book-Title        Book-Author  \
# 0                                     Flesh Tones: A Novel         M. J. Rose
# 1                                         Rites of Passage         Judith Rae
# 2                                             The Notebook    Nicholas Sparks
# 3                                           Help!: Level 1      Philip Prowse
# ...

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating': 'num_ratings'}, inplace=True)
num_rating_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title')['Book-Rating'].agg('mean').reset_index()
avg_rating_df.rename(columns={'Book-Rating': 'avg_ratings'}, inplace=True)
avg_rating_df
# Out:
#                                                Book-Title  avg_ratings
# 0        A Light in the Storm: The Civil War Diary of ...     2.250000
# 1                                   Always Have Popsicles     0.000000
# 2                    Apple Magic (The Collector's series)     0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...     8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...     0.000000
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.     0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.     5.250000
# 241068                                Ã?Â?sterlich leben.     7.000000
# 241069                              Ã?Â?stlich der Berge.     2.666667
# 241070                                  Ã?Â?thique en toc     4.000000
#
# [241071 rows x 2 columns]

# %%
popularity_df = avg_rating_df.merge(num_rating_df, on='Book-Title')
popularity_df
# Out:
#                                                Book-Title  avg_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...     2.250000
# 1                                   Always Have Popsicles     0.000000
# 2                    Apple Magic (The Collector's series)     0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...     8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...     0.000000
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.     0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.     5.250000
# 241068                                Ã?Â?sterlich leben.     7.000000
# 241069                              Ã?Â?stlich der Berge.     2.666667
# 241070                                  Ã?Â?thique en toc     4.000000
#
#         num_ratings
# 0                 4
# 1                 1
# 2                 1
# 3                 1
# ...

# %%
popularity_df = popularity_df[popularity_df['num_ratings']>=250].sort_values('avg_ratings', ascending=False)
popularity_df = popularity_df.head(50)
popularity_df
# Out:
#                                                Book-Title  avg_ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)     5.852804
# 80422        Harry Potter and the Goblet of Fire (Book 4)     5.824289
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)     5.737410
# 80426   Harry Potter and the Order of the Phoenix (Boo...     5.501441
# 80414    Harry Potter and the Chamber of Secrets (Book 2)     5.183453
# 191612  The Hobbit : The Enchanting Prelude to The Lor...     5.007117
# 187377  The Fellowship of the Ring (The Lord of the Ri...     4.948370
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...     4.895652
# 211384     The Two Towers (The Lord of the Rings, Part 2)     4.880769
# 219741                              To Kill a Mockingbird     4.700000
# 183573                                  The Da Vinci Code     4.642539
# 187880                 The Five People You Meet in Heaven     4.551163
# ...

# %%
popularity_df = popularity_df.merge(books, on='Book-Title').drop_duplicates('Book-Title')

# %%
popularity_df
# Out:
#                                             Book-Title  avg_ratings  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)     5.852804
# 3         Harry Potter and the Goblet of Fire (Book 4)     5.824289
# 5       Harry Potter and the Sorcerer's Stone (Book 1)     5.737410
# 9    Harry Potter and the Order of the Phoenix (Boo...     5.501441
# 13    Harry Potter and the Chamber of Secrets (Book 2)     5.183453
# 16   The Hobbit : The Enchanting Prelude to The Lor...     5.007117
# 17   The Fellowship of the Ring (The Lord of the Ri...     4.948370
# 26   Harry Potter and the Sorcerer's Stone (Harry P...     4.895652
# 28      The Two Towers (The Lord of the Rings, Part 2)     4.880769
# 39                               To Kill a Mockingbird     4.700000
# 47                                   The Da Vinci Code     4.642539
# 53                  The Five People You Meet in Heaven     4.551163
# 55                              The Catcher in the Rye     4.545657
# ...

# %%
popularity_df = popularity_df[['Book-Title', 'Book-Author','Year-Of-Publication','Image-URL-M', 'num_ratings', 'avg_ratings']]
popularity_df
# Out:
#                                             Book-Title  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)
# 3         Harry Potter and the Goblet of Fire (Book 4)
# 5       Harry Potter and the Sorcerer's Stone (Book 1)
# 9    Harry Potter and the Order of the Phoenix (Boo...
# 13    Harry Potter and the Chamber of Secrets (Book 2)
# 16   The Hobbit : The Enchanting Prelude to The Lor...
# 17   The Fellowship of the Ring (The Lord of the Ri...
# 26   Harry Potter and the Sorcerer's Stone (Harry P...
# 28      The Two Towers (The Lord of the Rings, Part 2)
# 39                               To Kill a Mockingbird
# 47                                   The Da Vinci Code
# 53                  The Five People You Meet in Heaven
# 55                              The Catcher in the Rye
# 62                           The Lovely Bones: A Novel
# 63                                                1984
# 72                            Prodigal Summer: A Novel
# ...

# %% [markdown]
# # Collaborative Filtering Based Recommender

# %%
x = ratings_with_name.groupby("User-ID").count()['Book-Rating'] > 200
book_reader_user = x[x].index

# %%
filter_rating = ratings_with_name[ratings_with_name['User-ID'].isin(book_reader_user)]

# %%
y = ratings_with_name.groupby('Book-Title').count()['Book-Rating']>=50
famous_books = y[y].index

# %%
famous_books
# Out:
# Index(['10 Lb. Penalty', '16 Lighthouse Road', '1984', '1st to Die: A Novel',
#        '2010: Odyssey Two', '204 Rosewood Lane', '2061: Odyssey Three',
#        '24 Hours', '2nd Chance', '3rd Degree',
#        ...
#        'YOU BELONG TO ME', 'Year of Wonders', 'You Belong To Me',
#        'You Shall Know Our Velocity', 'Young Wives',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"',
#        '\Surely You're Joking, Mr. Feynman!\": Adventures of a Curious Character"',
#        'stardust'],
#       dtype='object', name='Book-Title', length=2444)

# %%
final_rating = filter_rating[filter_rating['Book-Title'].isin(famous_books)]
final_rating
# Out:
#          User-ID        ISBN  Book-Rating  \
# 1150      277427  002542730X           10
# 1157      277427  0060177721            0
# 1162      277427  006092988X            0
# 1163      277427  0060930535            0
# 1164      277427  0060932139            0
# ...          ...         ...          ...
# 1029271   275970  1573229865            0
# 1029309   275970  1586210661            9
# 1029310   275970  1586212230            0
# 1029333   275970  1853260010            0
# 1029341   275970  1860462588            8
#
#                                                 Book-Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1157                                          Finding Moon
# 1162                              A Tree Grows in Brooklyn
# 1163                         The Poisonwood Bible: A Novel
# 1164     The Unbearable Lightness of Being : A Novel (P...
# ...                                                    ...
# ...

# %%
pt = final_rating.pivot_table(index="Book-Title", columns='User-ID', values="Book-Rating")
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 10 Lb. Penalty                                         NaN     NaN     NaN
# 16 Lighthouse Road                                     NaN     NaN     NaN
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     0.0     NaN
# ...                                                    ...     ...     ...
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
# \Surely You're Joking, Mr. Feynman!\": Adventur...     NaN     NaN     NaN
# stardust                                               0.0     NaN     NaN
#
# ...

# %%
pt.fillna(0, inplace=True)
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 10 Lb. Penalty                                         0.0     0.0     0.0
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \Surely You're Joking, Mr. Feynman!\": Adventur...     0.0     0.0     0.0
# stardust                                               0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_score = cosine_similarity(pt)

# %%
similarity_score.shape
# Out:
# (2444, 2444)

# %%
def recommend(book_name):
    index = np.where(pt.index == book_name)[0][0]
    distance = similarity_score[index]
    similar_items = sorted(list(enumerate(similarity_score[index])), key=lambda x: x[1], reverse=True)[1:20]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title' ] ==pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)        
        
    return data

# %%
recommend('Harry Potter and the Chamber of Secrets (Book 2)')
# Out:
# [['Harry Potter and the Prisoner of Azkaban (Book 3)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg'],
#  ['Harry Potter and the Goblet of Fire (Book 4)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0439139597.01.MZZZZZZZ.jpg'],
#  ["Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))",
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/059035342X.01.MZZZZZZZ.jpg'],
#  ["Harry Potter and the Sorcerer's Stone (Book 1)",
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0590353403.01.MZZZZZZZ.jpg'],
#  ['Harry Potter and the Order of the Phoenix (Book 5)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/043935806X.01.MZZZZZZZ.jpg'],
#  ["Charlotte's Web (Trophy Newbery)",
#   'E. B. White',
#   'http://images.amazon.com/images/P/0064400557.01.MZZZZZZZ.jpg'],
#  ['The Fellowship of the Ring (The Lord of the Rings, Part 1)',
#   'J.R.R. TOLKIEN',
# ...

# %%
import pickle

# %%
with open('popular.pkl', 'wb') as f:
    pickle.dump(popularity_df, f)

# %%
pickle.dump(pt,open('pt.pkl', 'wb'))
pickle.dump(books,open('books.pkl', 'wb'))
pickle.dump(similarity_score,open('similarity_score.pkl', 'wb'))

# %%
pt.index.tolist()
# Out:
# ['10 Lb. Penalty',
#  '16 Lighthouse Road',
#  '1984',
#  '1st to Die: A Novel',
#  '2010: Odyssey Two',
#  '204 Rosewood Lane',
#  '2061: Odyssey Three',
#  '24 Hours',
#  '2nd Chance',
#  '3rd Degree',
#  '4 Blondes',
#  '50 Simple Things You Can Do to Save the Earth',
#  '84 Charing Cross Road',
#  'A 2nd Helping of Chicken Soup for the Soul (Chicken Soup for the Soul Series (Paper))',
#  'A Beautiful Mind: The Life of Mathematical Genius and Nobel Laureate John Nash',
#  'A Bend in the Road',
#  'A Case of Need',
#  'A Child Called \\It\\": One Child\'s Courage to Survive"',
#  'A Civil Action',
#  'A Clockwork Orange (Norton Paperback Fiction)',
#  'A Cold Heart (Alex Delaware Novels (Paperback))',
#  'A Cold Heart: An Alex Delaware Novel',
#  'A Confederacy of Dunces',
#  'A Confederacy of Dunces (Evergreen Book)',
#  'A Cry In The Night',
#  "A Cup of Tea (Ballantine Reader's Circle)",
#  'A Dangerous Fortune',
#  'A Darkness More Than Night',
# ...

# %%
import json
columns = {
    'data_columns' : pt.index.tolist()
}
with open("books_name.json","w") as f:
    f.write(json.dumps(columns))
